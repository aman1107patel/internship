# %% [markdown]
# # Web Scrapping Assignment - 4
#
# Submitted by - Aman Kumar Patel .
#
# internship 25
#
# SME - md. kashif

# %%
# installing selenium 

# !pip install selenium

# %% [markdown]
# # Importing Required Libraries

# %%
#importing necessary libraries
import selenium
import pandas as pd
from bs4 import BeautifulSoup
import time

#Importing requests
import requests

# importing regex
import re

# Importing selenium webdriver
from selenium import webdriver

# Importing required Exceptions
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait

# importing warnings to avoid warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
# Activating the chrome browser

driver = webdriver.Chrome("C:/Users/Hp/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
# let's getting url

url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)

# %%
# now let's create a empty list 

Rank = []
Name = []
Artist = []
Upload_date = []
Views = []

# %%
# scrapping the data of Rank details

try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[1]")[:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
# scrapping the data of names of videos 

try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[2]")[:30]:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')

# %%
# scrapping the data of artist name

try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[3]")[:30]:
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append('-')

# %%
# scrapping the data of video upload dates

try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[4]")[:30]:
        Upload_date.append(i.text)
except NoSuchElementException:
    Upload_date.append('-')

# %%
# scrapping the data of video views

try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[5]")[:30]:
        Views.append(i.text)
except NoSuchElementException:
    Views.append('-')

# %%
# data framing of scrapped data

video = pd.DataFrame({})
video['Rank of video'] = Rank
video['Video Name'] = Name
video['Video Artist'] = Artist
video['Video Views'] = Upload_date
video['Uploaded Dates'] = Views

# %%
# shwoing the dataset

video
# Out:
#    Rank of video                                       Video Name  \
# 0             1.                            "Baby Shark Dance"[3]
# 1             2.                                   "Despacito"[6]
# 2             3.                       "Johny Johny Yes Papa"[12]
# 3             4.                               "Shape of You"[13]
# 4             5.                              "See You Again"[15]
# 5             6.                                  "Bath Song"[20]
# 6             7.                "Phonics Song with Two Words"[21]
# 7             8.  "Learning Colors – Colorful Eggs on a Farm"[22]
# 8             9.                                "Uptown Funk"[23]
# 9            10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10           11.                              "Gangnam Style"[25]
# 11           12.                          "Wheels on the Bus"[30]
# 12           13.                             "Dame Tu Cosita"[31]
# ...

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# creating the chrome

driver = webdriver.Chrome("chromedriver.exe")

# %%
# let's getting url

url = "https://www.bcci.tv/"
driver.get(url)

# %%
# clicking on the international 

int_btn = driver.find_element_by_xpath('/html/body/nav/div/div[2]/ul[1]/li[2]').click()

# %%
# clicking on the Fixture btn

fix_btn = driver.find_element_by_xpath("//a[@class='nav-link active ']")
try:
    fix_btn.click()
except ElementNotInteractableException:
    driver.get(fix_btn.get_attribute('href'))

# %%
# scrapping the match_title

Match = driver.find_elements_by_xpath("//span[@class='matchOrderText ng-binding ng-scope']")
len(Match)

Match_title=[]
for i in Match:
    Match_title.append(i.text)
Match_title
# Out:
# ['1st T20I -', '2nd T20I -', '3rd T20I -', '4th T20I -', '5th T20I -']

# %%
# scrapping the Series name

Series_er = driver.find_elements_by_xpath("//div[@class='fixture-tab-inner row']/div/div/div[1]/h5[2]/span")
len(Series_er)

Series = []
for j in Series_er:
    Series.append(j.text)
Series
# Out:
# ['SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022',
#  'SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022',
#  'SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022',
#  'SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022',
#  'SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022']

# %%
# scrapping the place_name

place = driver.find_elements_by_xpath("//span[@class='ng-binding ng-scope']")
len(place)

Place = []
for k in place:
    Place.append(k.text)
Place
# Out:
# ['Arun Jaitley Stadium,',
#  'Barabati Stadium,',
#  'Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadium,',
#  'Saurashtra Cricket Association Stadium,',
#  'M Chinnaswamy Stadium,']

# %%
# scrapping the date of match 

date = driver.find_elements_by_xpath("//div[@class='fixture-tab-inner row']/div/div/div[1]/div/div[1]/h5")
len(date)

Date = []
for k in date:
    Date.append(k.text)
Date
# Out:
# ['9 JUN 2022', '12 JUN 2022', '14 JUN 2022', '17 JUN 2022', '19 JUN 2022']

# %%
# scrapping the time of match

time = driver.find_elements_by_xpath("//div[@class='fixture-tab-inner row']/div/div/div[1]/div/div[2]/h5")
len(time)

Time = []
for k in time:
    Time.append(k.text)
Time
# Out:
# ['7:30 PM IST', '7:30 PM IST', '7:30 PM IST', '7:30 PM IST', '7:30 PM IST']

# %%
# creating dataframe

BCCI=pd.DataFrame()
BCCI['Match_title']= Match_title
BCCI['Series']= Series
BCCI['Place ']= Place
BCCI['Time']= Time
BCCI
# Out:
#   Match_title                                      Series  \
# 0  1st T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 1  2nd T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 2  3rd T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 3  4th T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 4  5th T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
#
#                                               Place          Time
# 0                              Arun Jaitley Stadium,  7:30 PM IST
# 1                                  Barabati Stadium,  7:30 PM IST
# 2  Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadium,  7:30 PM IST
# 3            Saurashtra Cricket Association Stadium,  7:30 PM IST
# 4                             M Chinnaswamy Stadium,  7:30 PM IST

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code

# %%
# getting the url

url = "https://www.guru99.com/"
driver.get(url)
time.sleep(3)

# %%
#Going to search bar and searching for selenium exception

ser_bar = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
ser_bar.send_keys("selenium exception handling")

# %%
# clicking the search button

ser_but = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button")
ser_but.click()

# %%
#Url of selenium exception handling page

urls = driver.find_element_by_xpath("//div[@class='gsc-expansionArea']//div//a")
page_url = urls.get_attribute("href")

driver.get(page_url)
time.sleep(5)

# %%
# calling the page_url

driver.get(page_url)
time.sleep(5)

# %%
#Scraping data of names of exceptions
Name = []
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[1]")[1:]:
    Name.append(i.text)

# %%
#Scraping data of descriptions of exceptions  

Description = []
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[2]")[1:]:
    Description.append(i.text)

# %%
# DATA FRAMEING

exception = pd.DataFrame({})
exception['Names of Exception'] = Name
exception['Descriptions of Exception'] = Description

# %%
# calling the dataset:

exception
# Out:
#                      Names of Exception  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# ...

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(18-19)
#
# D) GSDP(17-18)
#
# E) Share(2017)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code

# %%
# lets active the chrome

driver = webdriver.Chrome("chromedriver.exe")

# %%
# lets create with url

url = "http://statisticstimes.com/"
driver.get (url)
time.sleep(3)

# %%
# follow the instruction , we will choose the economy option

urls = driver.find_element_by_xpath("//div[@class='dropdown-content']//a[3]")
ind_page = urls.get_attribute("href")

# going to the india economy page

driver.get(ind_page)

# %% [markdown]
# it is unclickable so, i have call the url data of ind ecconomy

# %%
# get the url of page containing GDP of indian states

sta_GDP = driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
GDP_url = sta_GDP.get_attribute("href")

driver.get(GDP_url)
time.sleep(6)

# %% [markdown]
# stete Gdp is also unclickable so i have scrpped the urls data of the particular page,
# and now i can scrapped easily

# %%
#Creating empty list

Rank = []
State = []
Gsdp_1 = []
Gsdp_2 = []
Share = []
Gsdp = []

# %% [markdown]
# i am giong to scraped from id..because all required scrapped data is in form of horizental line, and it is suitlable form,so that is easy to scraped .

# %%
# scrapping the data of rank

for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[1]"):
    Rank.append(i.text)

# %%
# scrapping the data of state name

for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[2]"):
    State.append(i.text)

# %%
# scrapping the data of Gsdp_1

for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[3]"):
    Gsdp_1.append(i.text)

# %%
# scrapping the data of Gsdp_2

for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[4]"):
    Gsdp_2.append(i.text)

# %%
# scrapping the data of share

for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[5]"):
    Share.append(i.text)

# %%
#scrapping the data of Gsdp

for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[6]"):
    Gsdp.append(i.text)

# %%
#DATA FRAMEING
StatisticsTime=pd.DataFrame({})
StatisticsTime['Rank'] = Rank
StatisticsTime['State'] = State
StatisticsTime['Current GSDP (19-20)'] = Gsdp_1
StatisticsTime['current GSDP (18-19)'] = Gsdp_2
StatisticsTime['Share(18-19)'] = Share
StatisticsTime['GDP($ billion)'] = Gsdp

# %%
StatisticsTime
# Out:
#    Rank                      State Current GSDP (19-20) current GSDP (18-19)  \
# 0     1                Maharashtra                    -            2,632,792
# 1     2                 Tamil Nadu            1,845,853            1,630,208
# 2     3              Uttar Pradesh            1,687,818            1,584,764
# 3     4                    Gujarat                    -            1,502,899
# 4     5                  Karnataka            1,631,977            1,493,127
# 5     6                West Bengal            1,253,832            1,089,898
# 6     7                  Rajasthan            1,020,989              942,586
# 7     8             Andhra Pradesh              972,782              862,957
# 8     9                  Telangana              969,604              861,031
# 9    10             Madhya Pradesh              906,672              809,592
# 10   11                     Kerala                    -              781,653
# ...

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code

# %%
# lets active the chrome

driver=webdriver.Chrome('chromedriver.exe')

# %%
# getting the chrome

url = 'https://github.com/'
driver.get(url)

# %%
# scrapping the url

url = []
for i in driver.find_elements_by_xpath("//ul[@class='list-style-none f5 pb-1']/li[5]/a"):
    url.append(i.get_attribute('href'))
url
# Out:
# ['https://github.com/features/packages', 'https://github.com/trending']

# %%
# let's call the scrapped url

driver.get(url[1])

# %%
# scrapping the title

title = driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a")
len(title)

Repo_title = []
for j in title:
    Repo_title.append(j.text)
Repo_title
# Out:
# ['freeCodeCamp / freeCodeCamp',
#  'SebLague / Geographical-Adventures',
#  'pyscript / pyscript',
#  'programthink / zhao',
#  'microsoft / ML-For-Beginners',
#  'twbs / bootstrap',
#  'mvt-project / mvt',
#  'twostraws / simple-swiftui',
#  'programthink / books',
#  'justjavac / free-programming-books-zh_CN',
#  'Wechat-ggGitHub / Awesome-GitHub-Repo',
#  'dataabc / weiboSpider',
#  'papers-we-love / papers-we-love',
#  'Grasscutters / Grasscutter',
#  'ipfs / go-ipfs',
#  'PacktPublishing / The-Kaggle-Book',
#  'replicate / cog',
#  'appsmithorg / appsmith',
#  'pyodide / pyodide',
#  'ItsKaitlyn03 / OculusKiller',
#  'directus / directus',
#  'scottbez1 / smartknob',
#  'palantir / blueprint',
#  'Runc2333 / dingdong-helper-node',
#  'dotnet / docs']

# %%
# checking the length of tilte

len(Repo_title)
# Out:
# 25

# %%
# scrapping the description 

desc = driver.find_elements_by_xpath("//p[@class='col-9 color-fg-muted my-1 pr-4']")
len(desc)

description = []
for k in desc:
    description.append(k.text)
description
# Out:
# ["freeCodeCamp.org's open-source codebase and curriculum. Learn to code for free.",
#  '【编程随想】整理的《太子党关系网络》，专门揭露赵国的权贵',
#  '12 weeks, 26 lessons, 52 quizzes, classic Machine Learning for all',
#  'The most popular HTML, CSS, and JavaScript framework for developing responsive, mobile first projects on the web.',
#  'MVT (Mobile Verification Toolkit) helps with conducting forensics of mobile devices in order to find signs of a potential compromise.',
#  'A collection of small SwiftUI sample projects.',
#  '【编程随想】收藏的电子书清单（多个学科，含下载链接）',
#  '📚 免费的计算机编程类中文书籍，欢迎投稿',
#  '收集整理 GitHub 上高质量、有趣的开源项目。',
#  '新浪微博爬虫，用python爬取新浪微博数据',
#  'Papers from the computer science community to read and discuss.',
#  'A server software reimplementation for a certain anime game.',
#  'IPFS implementation in Go',
#  'Code Repository for The Kaggle Book, Published by Packt Publishing',
#  'Containers for machine learning',
# ...

# %%
# checking the length

len(description)
# Out:
# 23

# %%
# completing the length of description

description.insert(15,"NA")
description.insert(20,"NA")

# %%
# checking the length of description

len(description)
# Out:
# 25

# %%
# scrapping cont. 

cont = driver.find_elements_by_xpath("//div[@class='f6 color-fg-muted mt-2']/a[2]")
len(cont)

counts = []
for k in cont:
    counts.append(k.text)
counts
# Out:
# ['28,579',
#  '155',
#  '274',
#  '2,446',
#  '6,764',
#  '76,622',
#  '628',
#  '20',
#  '2,661',
#  '26,011',
#  '458',
#  '1,544',
#  '4,748',
#  '1,605',
#  '2,606',
#  '122',
#  '61',
#  '1,362',
#  '502',
#  '7',
#  '1,763',
#  '449',
#  '2,000',
#  '47',
#  '5,098']

# %%
# checking length of cont.

len(counts)
# Out:
# 25

# %%
# scrapping the language

lang = driver.find_elements_by_xpath("//span[@class='d-inline-block ml-0 mr-3']/span[2]")
len(lang)

Language = []
for k in lang:
    Language.append(k.text)
Language
# Out:
# ['TypeScript',
#  'C#',
#  'JavaScript',
#  'Python',
#  'Jupyter Notebook',
#  'JavaScript',
#  'Python',
#  'Swift',
#  'Python',
#  'Shell',
#  'Java',
#  'Go',
#  'Jupyter Notebook',
#  'Go',
#  'TypeScript',
#  'Python',
#  'C#',
#  'TypeScript',
#  'C++',
#  'TypeScript',
#  'JavaScript']

# %%
# checkling the length 

len(Language)
# Out:
# 21

# %%
# completing the language

Language1=Language
Language1.insert(2,"NA")
Language2=Language
Language2.insert(11,"NA")
Language3=Language
Language3.insert(13,"NA")
Language4=Language
Language4.insert(20,"NA")

# %%
# checking the length

len(Language)
# Out:
# 25

# %%
# data framing

trending=pd.DataFrame()
trending['Repository_title']= Repo_title
trending['Repository_description']= description
trending['Contributors_count']= counts
trending['Language_Used']= Language
trending
# Out:
#                             Repository_title  \
# 0                freeCodeCamp / freeCodeCamp
# 1         SebLague / Geographical-Adventures
# 2                        pyscript / pyscript
# 3                        programthink / zhao
# 4               microsoft / ML-For-Beginners
# 5                           twbs / bootstrap
# 6                          mvt-project / mvt
# 7                 twostraws / simple-swiftui
# 8                       programthink / books
# 9   justjavac / free-programming-books-zh_CN
# 10     Wechat-ggGitHub / Awesome-GitHub-Repo
# 11                     dataabc / weiboSpider
# 12           papers-we-love / papers-we-love
# 13                Grasscutters / Grasscutter
# 14                            ipfs / go-ipfs
# 15         PacktPublishing / The-Kaggle-Book
# 16                           replicate / cog
# 17                    appsmithorg / appsmith
# 18                         pyodide / pyodide
# 19               ItsKaitlyn03 / OculusKiller
# ...

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# lets active the chrome

driver=webdriver.Chrome('chromedriver.exe')

# %%
# connecting chrome with the url 

url = "https:/www.billboard.com/"
driver.get(url)

# %%
# scrapping the url page

Urls=[]
for i in driver.find_elements_by_xpath("//li[@class='o-nav__list-item lrv-u-align-items-center lrv-u-flex']/a"):
    Urls.append(i.get_attribute("href"))
Urls
# Out:
# ['https://www.billboard.com/charts',
#  'https://www.billboard.com/c/music/',
#  'https://www.billboard.com/c/culture/',
#  'https://www.billboard.com/c/media/',
#  'https://www.billboard.com/pro']

# %%
# calling charts url

driver.get(Urls[0])

# %%
# clicking on hot 100

hot=driver.find_element_by_xpath('/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span')
hot.click()

# %%
# scarpping the song name

name=driver.find_elements_by_xpath('//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]/div/ul/li[4]/ul/li/h3')
len(name)

Song_name=[]
for j in name:
    Song_name.append(j.text)
Song_name
# Out:
# ['As It Was',
#  'First Class',
#  'Heat Waves',
#  'Big Energy',
#  'Enemy',
#  'Stay',
#  'Woman',
#  'Ghost',
#  'Super Gremlin',
#  'Thats What I Want',
#  'Bad Habits',
#  'Shivers',
#  'abcdefu',
#  'Cold Heart (PNAU Remix)',
#  'Thousand Miles',
#  'Save Your Tears',
#  'One Right Now',
#  'Levitating',
#  'Need To Know',
#  'MAMIII',
#  'Bam Bam',
#  'Industry Baby',
#  "'Til You Can't",
#  'Easy On Me',
#  'In A Minute',
#  "Doin' This",
#  'Wasted On You',
#  'AA',
#  'Plan B',
#  'Hrs And Hrs',
#  'Boyfriend',
#  'Sweetest Pie',
#  'Trouble With A Heartbreak',
#  'Right On',
#  'Good 4 U',
#  'Provenza',
#  'Numb Little Bug',
#  'To The Moon!',
#  'I Hate U',
#  "We Don't Talk About Bruno",
#  'Never Say Never',
#  "Don't Think Jesus",
#  'You Right',
#  'Fingers Crossed',
#  'Fancy Like',
#  'Sand In My Boots',
#  "She's All I Wanna Be",
#  'The Motto',
#  'What Happened To Virgil',
#  "When You're Gone",
#  '2step',
#  'Beers On Me',
#  'Pushin P',
#  'Freaky Deaky',
# ...

# %%
# checking the length of song_name

len(Song_name)
# Out:
# 100

# %%
# scrraping the artist name

Artist=driver.find_elements_by_xpath('//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]/div/ul/li[4]/ul/li[1]/span')
len(Artist)

artist_name=[]
for k in Artist:
    artist_name.append(k.text)
artist_name
# Out:
# ['Harry Styles',
#  'Jack Harlow',
#  'Glass Animals',
#  'Latto',
#  'Imagine Dragons X JID',
#  'The Kid LAROI & Justin Bieber',
#  'Doja Cat',
#  'Justin Bieber',
#  'Kodak Black',
#  'Lil Nas X',
#  'Ed Sheeran',
#  'Ed Sheeran',
#  'GAYLE',
#  'Elton John & Dua Lipa',
#  'The Kid LAROI',
#  'The Weeknd & Ariana Grande',
#  'Post Malone & The Weeknd',
#  'Dua Lipa',
#  'Doja Cat',
#  'Becky G X Karol G',
#  'Camila Cabello Featuring Ed Sheeran',
#  'Lil Nas X & Jack Harlow',
#  'Cody Johnson',
#  'Adele',
#  'Lil Baby',
#  'Luke Combs',
#  'Morgan Wallen',
#  'Walker Hayes',
#  'Megan Thee Stallion',
#  'Muni Long',
#  'Dove Cameron',
#  'Megan Thee Stallion & Dua Lipa',
#  'Jason Aldean',
#  'Lil Baby',
#  'Olivia Rodrigo',
#  'Karol G',
#  'Em Beihold',
#  'JNR CHOI & Sam Tompkins',
#  'SZA',
#  'Carolina Gaitan, Mauro Castillo, Adassa, Rhenzy Feliz, Diane Guerrero, Stephanie Beatriz & Encanto Cast',
#  'Cole Swindell / Lainey Wilson',
#  'Morgan Wallen',
# ...

# %%
# checking the length of artist name

len(artist_name)
# Out:
# 100

# %%
# scrapping the week pee rank

wrank=driver.find_elements_by_xpath('//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]/div/ul/li[4]/ul/li[4]/span')
len(wrank)

Last_week_rank=[]
for k in wrank:
    Last_week_rank.append(k.text)
Last_week_rank
# Out:
# ['1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '8',
#  '10',
#  '9',
#  '11',
#  '12',
#  '14',
#  '13',
#  '15',
#  '-',
#  '18',
#  '19',
#  '21',
#  '17',
#  '24',
#  '25',
#  '23',
#  '22',
#  '16',
#  '20',
#  '30',
#  '31',
#  '32',
#  '-',
#  '26',
#  '37',
#  '34',
#  '59',
#  '28',
#  '33',
#  '-',
#  '40',
#  '38',
#  '36',
#  '27',
#  '29',
#  '7',
#  '39',
#  '35',
#  '41',
#  '42',
#  '47',
#  '46',
#  '43',
#  '48',
#  '-',
#  '45',
#  '44',
#  '57',
#  '-',
#  '54',
#  '-',
#  '53',
#  '-',
#  '50',
#  '-',
#  '64',
#  '66',
#  '52',
#  '58',
#  '67',
#  '60',
#  '55',
#  '62',
#  '65',
#  '56',
#  '69',
#  '73',
#  '75',
#  '63',
#  '-',
#  '70',
#  '-',
#  '68',
#  '72',
#  '-',
#  '77',
#  '76',
#  '71',
#  '51',
#  '81',
#  '74',
#  '89',
#  '78',
#  '80',
#  '86',
#  '-',
#  '88',
#  '82',
#  '91',
#  '87',
#  '94',
#  '92',
#  '84',
#  '-']

# %%
# checking the length

len(Last_week_rank)
# Out:
# 100

# %%
# scrraoing the peak rank

peak=driver.find_elements_by_xpath('//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]/div/ul/li[4]/ul/li[5]/span')
len(peak)

Peak_rank=[]
for k in peak:
    Peak_rank.append(k.text)
Peak_rank
# Out:
# ['1',
#  '1',
#  '1',
#  '3',
#  '5',
#  '1',
#  '7',
#  '5',
#  '3',
#  '8',
#  '2',
#  '4',
#  '3',
#  '7',
#  '15',
#  '1',
#  '6',
#  '2',
#  '8',
#  '15',
#  '21',
#  '1',
#  '18',
#  '1',
#  '14',
#  '26',
#  '9',
#  '28',
#  '29',
#  '16',
#  '31',
#  '15',
#  '33',
#  '13',
#  '1',
#  '36',
#  '37',
#  '38',
#  '7',
#  '1',
#  '27',
#  '7',
#  '11',
#  '19',
#  '3',
#  '30',
#  '44',
#  '42',
#  '22',
#  '38',
#  '51',
#  '40',
#  '7',
#  '43',
#  '55',
#  '53',
#  '57',
#  '53',
#  '59',
#  '50',
#  '61',
#  '43',
#  '63',
#  '27',
#  '50',
#  '58',
#  '14',
#  '55',
#  '13',
#  '64',
#  '18',
#  '69',
#  '68',
#  '74',
#  '8',
#  '76',
#  '40',
#  '78',
#  '18',
#  '2',
#  '81',
#  '52',
#  '76',
#  '70',
#  '51',
#  '71',
#  '51',
#  '86',
#  '33',
#  '20',
#  '86',
#  '32',
#  '61',
#  '81',
#  '91',
#  '87',
#  '88',
#  '77',
#  '46',
#  '100']

# %%
# checking the length

len(Peak_rank)
# Out:
# 100

# %%
# scraping the weeks on baord

weeks=driver.find_elements_by_xpath('//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]/div/ul/li[4]/ul/li[6]/span')
len(weeks)

Weeks_on_board=[]
for k in weeks:
    Weeks_on_board.append(k.text)
Weeks_on_board
# Out:
# ['4',
#  '3',
#  '67',
#  '27',
#  '23',
#  '42',
#  '39',
#  '31',
#  '25',
#  '32',
#  '44',
#  '33',
#  '23',
#  '34',
#  '1',
#  '69',
#  '25',
#  '77',
#  '46',
#  '11',
#  '8',
#  '40',
#  '29',
#  '29',
#  '3',
#  '20',
#  '24',
#  '16',
#  '1',
#  '18',
#  '11',
#  '7',
#  '6',
#  '3',
#  '50',
#  '1',
#  '13',
#  '9',
#  '21',
#  '18',
#  '15',
#  '2',
#  '43',
#  '17',
#  '45',
#  '41',
#  '12',
#  '13',
#  '7',
#  '4',
#  '1',
#  '18',
#  '16',
#  '9',
#  '1',
#  '13',
#  '1',
#  '13',
#  '1',
#  '2',
#  '1',
#  '10',
#  '16',
#  '14',
#  '18',
#  '16',
#  '19',
#  '2',
#  '17',
#  '14',
#  '10',
#  '9',
#  '21',
#  '4',
#  '18',
#  '2',
#  '8',
#  '1',
#  '10',
#  '12',
#  '1',
#  '16',
#  '4',
#  '5',
#  '2',
#  '15',
#  '13',
#  '6',
#  '4',
#  '5',
#  '2',
#  '3',
#  '10',
#  '13',
#  '4',
#  '7',
#  '3',
#  '6',
#  '10',
#  '1']

# %%
# checking the length of of weeks on baoard

len(Weeks_on_board)
# Out:
# 100

# %%
# Data Framing

HOT=pd.DataFrame()

HOT['Song_name']= Song_name
HOT['Artist_name ']= artist_name
HOT['Last_week_rank']= Last_week_rank
HOT['Peak_rank']= Peak_rank
HOT['Weeks_on_board']= Weeks_on_board
HOT
# Out:
#         Song_name                             Artist_name  Last_week_rank  \
# 0       As It Was                             Harry Styles              1
# 1     First Class                              Jack Harlow              2
# 2      Heat Waves                            Glass Animals              3
# 3      Big Energy                                    Latto              4
# 4           Enemy                    Imagine Dragons X JID              5
# ..            ...                                      ...            ...
# 95          Bones                          Imagine Dragons             87
# 96  Hate Our Love                   Queen Naija & Big Sean             94
# 97           Over                               Lucky Daye             92
# 98   City Of Gods  Fivio Foreign, Kanye West & Alicia Keys             84
# 99     Brambleton                                  Pusha T              -
#
#    Peak_rank Weeks_on_board
# 0          1              4
# ...

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
# calling the special url

url = 'https://www.naukri.com/' 

driver.get(url)

# %%
# searching "Data Scientitst" in search columns

search_field_designation = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[1]/div/div/div/input").send_keys("Data science")

# %%
# clicking on search btn

search_field_designation = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[6]").click()

# %%
# Fetching urls for recruiter page

rec = driver.find_element_by_xpath("//a[@title='Search Recruiters']")
page_url = rec.get_attribute("href")

driver.get(page_url)

# %%
# clciking the Data Scienctist

search_field_designation = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input").send_keys("Data science")

# %%
# clciking on search_button

search_field_designation = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button").click()

# %%
# Creating empty list

Name = []
Designation = []
Company = []
Skills = []
Location = []

# %%
#Scraping data of Names

for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']"):
    Name.append(i.text)

# %%
# scrapping drscription 

for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']"):
    Designation.append(i.text)

# %%
# Scrapping Company name 

for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)

# %%
# scrapping the skills

for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']"):
    Skills.append(i.text)

# %%
# scrapping location 

for i in driver.find_elements_by_xpath("//div[@class='vcard']"):
    Location.append(i.text)

# %%
#DATA FRAMEING

Naukri=pd.DataFrame({})
Naukri['Name'] = Name
Naukri['Designation'] = Designation
Naukri['Company'] = Company
Naukri['Skills'] = Skills

# %%
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# ...

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
#Activating the chrome browser

driver = webdriver.Chrome("chromedriver.exe")

# %%
# getting url

url = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/'
driver.get(url)

# %%
#Creating empty list

Book_name = []
Author = []
Volumes_sold = []
Publisher = []
Genre = []

# %%
# scrapping the book names

for i in driver.find_elements_by_xpath("//tbody//tr//td[2]"):
    Book_name.append(i.text)

# %%
len(Book_name)
# Out:
# 100

# %%
# scrapping the author name

for i in driver.find_elements_by_xpath("//tbody//tr//td[3]"):
    Author.append(i.text)

# %%
len(Author)
# Out:
# 100

# %%
# scrapping the number of volume sold

for i in driver.find_elements_by_xpath("//tbody//tr//td[4]"):
    Volumes_sold.append(i.text)

# %%
len(Volumes_sold)
# Out:
# 100

# %%
# scrapping the publisher

for i in driver.find_elements_by_xpath("//tbody//tr//td[5]"):
    Publisher.append(i.text)

# %%
len(Publisher)
# Out:
# 100

# %%
# scrapping the genre

for i in driver.find_elements_by_xpath("//tbody//tr//td[6]"):
    Genre.append(i.text)

# %%
len(Genre)
# Out:
# 100

# %%
#DATA FRAMEING

Novel=pd.DataFrame({})
Novel['Book Name'] = Book_name
Novel['Author'] = Author
Novel['Volume sold'] = Volumes_sold
Novel['Publisher'] = Publisher
Novel['Genre'] = Genre
Novel
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# ...

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
# calling url

url = ' https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
#Creating empty lists.

Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# %%
#Scraping data of Names
for i in driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a"):
    Name.append(i.text)

    
#Scraping data of Year span
for i in driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)

    
#Scraping data of genre
for i in driver.find_elements_by_xpath("//span[@class='genre']"):
    Genre.append(i.text)

    
#Scraping data of Run time
for i in driver.find_elements_by_xpath("//span[@class='runtime']"):
    Run_time.append(i.text)

    
#Scraping data of Ratings
for i in driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)

    
#Scraping data of votes
for i in driver.find_elements_by_xpath("//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)

# %%
#DATA FRAMEING
IMDB=pd.DataFrame({})
IMDB['Name'] = Name
IMDB['Year Span'] = Year_span
IMDB['Genre'] = Genre
IMDB['Run Time'] = Run_time
IMDB['Ratings'] = Ratings
IMDB['Votes'] = Votes

# %%
IMDB
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,980,785
# ...

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
# calling the url

url = 'https://archive.ics.uci.edu/'
driver.get(url)

# %%
#Finding view all dataset button

view_dataset = driver.find_element_by_xpath("//tbody[1]//tr/td[2]/span[2]/a")    
page_url = view_dataset.get_attribute("href")
driver.get(page_url)
time.sleep(5)

# %%
#Getting page urls containing list of all datasets

all_lst = driver.find_element_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")  
lst_url = all_lst.get_attribute("href")           
driver.get(lst_url)
time.sleep(5)

# %%
#fetching url for each dataset

data_url = driver.find_elements_by_xpath("//p[@class='normal']//b/a")    

urls = []     
for i in data_url:
    urls.append(i.get_attribute("href"))

# %%
#Creating empty list
Data_name = []
Data_type = []
Task = []
Attr_type = []
Instances = []
n_attributes = []
Year = []

# %%
#Scraping requiredinfo from urls
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    
    #Scraping Dataset name
    try: 
        ds_name = driver.find_element_by_xpath("//span[@class='heading']")
        Data_name.append(ds_name.text)
    except NoSuchElementException:
        Data_name.append('-')
    time.sleep(1)
    
    
    #Scraping data type
    try:
        dtype = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[2]")
        if dtype.text == "N/A": raise NoSuchElementException
        Data_type.append(dtype.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(1)
    
    
    #Scraping Attribute type
    try:
        atype = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[2]")
        if atype.text == "N/A": raise NoSuchElementException
        Attr_type.append(atype.text)
    except NoSuchElementException:
        Attr_type.append('-')
    time.sleep(1)
    
    
    #scraping Task
    try:
        task = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(1)
    
    
    #Scraping No of instances
    try:
        inst = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[4]")
        if inst.text == "N/A": raise NoSuchElementException
        Instances.append(inst.text)
    except NoSuchElementException:
        Instances.append('-')
    time.sleep(1)
    
    
    #Scraping  No of attribute
    try:
        attr = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[4]")
        if attr.text == "N/A": raise NoSuchElementException
        n_attributes.append(attr.text)
    except NoSuchElementException:
        n_attributes.append('-')
    time.sleep(1)
    
    
    #scraping year
    try:
        year = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(1)

# %%
# data framing

UCI=pd.DataFrame({})
UCI['Data Name'] = Data_name
UCI['Data Type'] = Data_type
UCI['Task'] = Task
UCI['Attribute type'] = Attr_type
UCI['No of instance'] = Instances
UCI['No of attributes'] = n_attributes
UCI['Year'] = Year

UCI
# Out:
#                                              Data Name  \
# 0         2.4 GHZ Indoor Channel Measurements Data Set
# 1    3D Road Network (North Jutland, Denmark) Data Set
# 2                                  3W dataset Data Set
# 3                          9mers from cullpdb Data Set
# 4    : Simulated Data set of Iraqi tourism places D...
# ..                                                 ...
# 851  Youtube cookery channels viewers comments in H...
# 852     YouTube Multiview Video Games Dataset Data Set
# 853                   YouTube Spam Collection Data Set
# 854                           Z-Alizadeh Sani Data Set
# 855                                       Zoo Data Set
#
#                      Data Type                        Task  \
# 0                 Multivariate              Classification
# 1             Sequential, Text      Regression, Clustering
# 2    Multivariate, Time-Series  Classification, Clustering
# 3                   Sequential  Classification, Regression
# ...

# %% [markdown]
# # DONE :)
